# %% [markdown]
# #This notebook combine the TripFare data and the neighborhood for later analysis

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ###read the data of trip fare, and neighborhoods

# %%
#DataFrame for trip_fare data
df = pd.read_csv('tripfare_join_1312')

# %%
#Series for neighborhoods
s = pd.read_csv('neighborhood12.txt', header=False)

# %%
df
# Out:
#          00005007A9F30E289E760362F69E4EAD 11DD39E40329CFF79635A99A574E0E8B CMT 2013-12-01 10:00:22\t1  \
# 0         00005007A9F30E289E760362F69E4EAD 11DD39E40329C...
# 1         00005007A9F30E289E760362F69E4EAD 11DD39E40329C...
# 2         00005007A9F30E289E760362F69E4EAD 11DD39E40329C...
# 3         00005007A9F30E289E760362F69E4EAD 11DD39E40329C...
# 4         00005007A9F30E289E760362F69E4EAD 11DD39E40329C...
# 5         00005007A9F30E289E760362F69E4EAD 11DD39E40329C...
# 6         00005007A9F30E289E760362F69E4EAD 11DD39E40329C...
# 7         00005007A9F30E289E760362F69E4EAD 11DD39E40329C...
# 8         00005007A9F30E289E760362F69E4EAD 11DD39E40329C...
# 9         00005007A9F30E289E760362F69E4EAD 11DD39E40329C...
# 10        00005007A9F30E289E760362F69E4EAD 11DD39E40329C...
# 11        00005007A9F30E289E760362F69E4EAD 11DD39E40329C...
# 12        00005007A9F30E289E760362F69E4EAD 24C122A944FB8...
# 13        00005007A9F30E289E760362F69E4EAD 24C122A944FB8...
# ...

# %% [markdown]
# ###join the DataFrame and the Series

# %%
dfs = df.join(s)

# %%
dfs.to_csv('trip_fare_neighbor_12.csv', index=False)
